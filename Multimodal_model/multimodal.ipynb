# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import fitz  # PyMuPDF
from langchain_core.documents import Document
from transformers import CLIPProcessor, CLIPModel
from PIL import Image
import torch
import numpy as np
from langchain.chat_models import init_chat_model
from langchain.prompts import PromptTemplate
from langchain.schema.messages import HumanMessage
from sklearn.metrics.pairwise import cosine_similarity
import os
import base64
import io
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS

# %%
### initialize the Clip Model for unified embeddings
clip_model=CLIPModel.from_pretrained("openai/clip-vit-base-patch32")
clip_processor=CLIPProcessor.from_pretrained("openai/clip-vit-base-patch32")
clip_model.eval()
# Out:
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.52, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# Fetching 1 files: 100%|██████████| 1/1 [00:00<?, ?it/s]
# CLIPModel(
#   (text_model): CLIPTextTransformer(
#     (embeddings): CLIPTextEmbeddings(
#       (token_embedding): Embedding(49408, 512)
#       (position_embedding): Embedding(77, 512)
#     )
#     (encoder): CLIPEncoder(
#       (layers): ModuleList(
#         (0-11): 12 x CLIPEncoderLayer(
#           (self_attn): CLIPAttention(
#             (k_proj): Linear(in_features=512, out_features=512, bias=True)
#             (v_proj): Linear(in_features=512, out_features=512, bias=True)
#             (q_proj): Linear(in_features=512, out_features=512, bias=True)
#             (out_proj): Linear(in_features=512, out_features=512, bias=True)
#           )
#           (layer_norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (mlp): CLIPMLP(
#             (activation_fn): QuickGELUActivation()
#             (fc1): Linear(in_features=512, out_features=2048, bias=True)
#             (fc2): Linear(in_features=2048, out_features=512, bias=True)
#           )
#           (layer_norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#     (final_layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#   )
#   (vision_model): CLIPVisionTransformer(
#     (embeddings): CLIPVisionEmbeddings(
#       (patch_embedding): Conv2d(3, 768, kernel_size=(32, 32), stride=(32, 32), bias=False)
#       (position_embedding): Embedding(50, 768)
#     )
#     (pre_layrnorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (encoder): CLIPEncoder(
#       (layers): ModuleList(
#         (0-11): 12 x CLIPEncoderLayer(
#           (self_attn): CLIPAttention(
#             (k_proj): Linear(in_features=768, out_features=768, bias=True)
#             (v_proj): Linear(in_features=768, out_features=768, bias=True)
#             (q_proj): Linear(in_features=768, out_features=768, bias=True)
#             (out_proj): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (layer_norm1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (mlp): CLIPMLP(
#             (activation_fn): QuickGELUActivation()
#             (fc1): Linear(in_features=768, out_features=3072, bias=True)
#             (fc2): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (layer_norm2): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#     (post_layernorm): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#   )
#   (visual_projection): Linear(in_features=768, out_features=512, bias=False)
#   (text_projection): Linear(in_features=512, out_features=512, bias=False)
# )

# %%
import os
from dotenv import load_dotenv
from langchain_google_genai import GoogleGenerativeAI

# Load environment variables
load_dotenv()

# Create LLM with explicit API key
llm = GoogleGenerativeAI(
    model="gemini-2.5-pro",  # Use correct model name
    google_api_key=os.getenv('GOOGLE_API_KEY')  # Explicit API key
)

# %%
# creating the embedding fucntions

def embed_image(image_data):
    """embedding the image using clip"""

    if isinstance(image_data,str):
        image = Image.open(image_data).convert("RGB")
    else:    #if PIL image
         image = image_data

    inputs = clip_processor(images=image,return_tensors="pt")
    with torch.no_grad():
        features = clip_model.get_image_features(**inputs)
        #normalizing embeddings to unit vector
        features = features/features.norm(dim=1,keepdim=True)
        return features.squeeze().numpy()
    

def embed_text(text):
    """Embed the text using clip"""
    inputs = clip_processor(text=text,return_tensors="pt",padding = True,truncation = True,max_length = 77)# 77 is clips max token length
    with torch.no_grad():
        features =clip_model.get_text_features(**inputs)
        features = features/features.norm(dim=1,keepdim=True)
        return features.squeeze().numpy()

# %%
# processing the PDF fucntion

## Process PDF
pdf_path="G:\AGENTIC_FRAMEWORK\data\Flowers.pdf"
doc=fitz.open(pdf_path)
# Storage for all documents and embeddings
all_docs = []
all_embeddings = []
image_data_store = {}  # Store actual image data for LLM

# Text splitter
splitter = RecursiveCharacterTextSplitter(chunk_size=500, chunk_overlap=100)

# %%
doc
# Out:
# Document('G:\AGENTIC_FRAMEWORK\data\Flowers.pdf')

# %%
#processing the text and images

for i , page in enumerate(doc):

    ## process the text
    text = page.get_text()
    if text.strip():
        ## create tem documents for spliting
        temp_doc = Document(page_content=text,metadata={"page":i,"type":"text"})
        text_chunks = splitter.split_documents([temp_doc])

        #embed each chunk using clip
        for chunk in text_chunks:
            embedding = embed_text(chunk.page_content)
            all_embeddings.append(embedding)
            all_docs.append(chunk)

    ##process the images

    ##Convert PDF image to PIL format
    ##Store as base64 for GPT-4V (which needs base64 images)
    ##Create CLIP embedding for retrieval
    
    for img_index, img in enumerate(page.get_images(full=True)):
        try:
            xref = img[0]
            base_image = doc.extract_image(xref)
            image_bytes = base_image["image"]
            
            # Convert to PIL Image
            pil_image = Image.open(io.BytesIO(image_bytes)).convert("RGB")
            
            # Create unique identifier
            image_id = f"page_{i}_img_{img_index}"
            
            # Store image as base64 for later use with GPT-4V
            buffered = io.BytesIO()
            pil_image.save(buffered, format="PNG")
            img_base64 = base64.b64encode(buffered.getvalue()).decode()
            image_data_store[image_id] = img_base64
            
            # Embed image using CLIP
            embedding = embed_image(pil_image)
            all_embeddings.append(embedding)
            
            # Create document for image
            image_doc = Document(
                page_content=f"[Image: {image_id}]",
                metadata={"page": i, "type": "image", "image_id": image_id}
            )
            all_docs.append(image_doc)
            
        except Exception as e:
            print(f"Error processing image {img_index} on page {i}: {e}")
            continue

doc.close()

# %%
all_docs
# Out:
# [Document(metadata={'page': 0, 'type': 'text'}, page_content='Morphology of flower'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_0'}, page_content='[Image: page_0_img_0]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_1'}, page_content='[Image: page_0_img_1]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_2'}, page_content='[Image: page_0_img_2]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_3'}, page_content='[Image: page_0_img_3]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_4'}, page_content='[Image: page_0_img_4]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_5'}, page_content='[Image: page_0_img_5]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_6'}, page_content='[Image: page_0_img_6]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_7'}, page_content='[Image: page_0_img_7]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_8'}, page_content='[Image: page_0_img_8]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_9'}, page_content='[Image: page_0_img_9]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_10'}, page_content='[Image: page_0_img_10]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_11'}, page_content='[Image: page_0_img_11]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_12'}, page_content='[Image: page_0_img_12]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_13'}, page_content='[Image: page_0_img_13]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_14'}, page_content='[Image: page_0_img_14]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_15'}, page_content='[Image: page_0_img_15]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_16'}, page_content='[Image: page_0_img_16]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_17'}, page_content='[Image: page_0_img_17]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_18'}, page_content='[Image: page_0_img_18]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_19'}, page_content='[Image: page_0_img_19]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_20'}, page_content='[Image: page_0_img_20]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_21'}, page_content='[Image: page_0_img_21]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_22'}, page_content='[Image: page_0_img_22]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_23'}, page_content='[Image: page_0_img_23]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_24'}, page_content='[Image: page_0_img_24]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_25'}, page_content='[Image: page_0_img_25]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_26'}, page_content='[Image: page_0_img_26]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_27'}, page_content='[Image: page_0_img_27]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_28'}, page_content='[Image: page_0_img_28]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_29'}, page_content='[Image: page_0_img_29]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_30'}, page_content='[Image: page_0_img_30]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_31'}, page_content='[Image: page_0_img_31]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_32'}, page_content='[Image: page_0_img_32]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_33'}, page_content='[Image: page_0_img_33]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_34'}, page_content='[Image: page_0_img_34]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_35'}, page_content='[Image: page_0_img_35]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_36'}, page_content='[Image: page_0_img_36]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_37'}, page_content='[Image: page_0_img_37]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_38'}, page_content='[Image: page_0_img_38]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_39'}, page_content='[Image: page_0_img_39]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_40'}, page_content='[Image: page_0_img_40]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_41'}, page_content='[Image: page_0_img_41]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_42'}, page_content='[Image: page_0_img_42]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_43'}, page_content='[Image: page_0_img_43]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_44'}, page_content='[Image: page_0_img_44]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_45'}, page_content='[Image: page_0_img_45]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_46'}, page_content='[Image: page_0_img_46]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_47'}, page_content='[Image: page_0_img_47]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_48'}, page_content='[Image: page_0_img_48]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_49'}, page_content='[Image: page_0_img_49]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_50'}, page_content='[Image: page_0_img_50]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_51'}, page_content='[Image: page_0_img_51]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_52'}, page_content='[Image: page_0_img_52]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_53'}, page_content='[Image: page_0_img_53]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_54'}, page_content='[Image: page_0_img_54]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_55'}, page_content='[Image: page_0_img_55]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_56'}, page_content='[Image: page_0_img_56]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_57'}, page_content='[Image: page_0_img_57]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_58'}, page_content='[Image: page_0_img_58]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_59'}, page_content='[Image: page_0_img_59]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_60'}, page_content='[Image: page_0_img_60]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_61'}, page_content='[Image: page_0_img_61]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_62'}, page_content='[Image: page_0_img_62]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_63'}, page_content='[Image: page_0_img_63]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_64'}, page_content='[Image: page_0_img_64]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_65'}, page_content='[Image: page_0_img_65]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_66'}, page_content='[Image: page_0_img_66]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_67'}, page_content='[Image: page_0_img_67]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_68'}, page_content='[Image: page_0_img_68]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_69'}, page_content='[Image: page_0_img_69]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_70'}, page_content='[Image: page_0_img_70]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_71'}, page_content='[Image: page_0_img_71]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_72'}, page_content='[Image: page_0_img_72]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_73'}, page_content='[Image: page_0_img_73]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_74'}, page_content='[Image: page_0_img_74]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_75'}, page_content='[Image: page_0_img_75]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_76'}, page_content='[Image: page_0_img_76]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_77'}, page_content='[Image: page_0_img_77]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_78'}, page_content='[Image: page_0_img_78]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_79'}, page_content='[Image: page_0_img_79]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_80'}, page_content='[Image: page_0_img_80]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_81'}, page_content='[Image: page_0_img_81]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_82'}, page_content='[Image: page_0_img_82]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_83'}, page_content='[Image: page_0_img_83]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_84'}, page_content='[Image: page_0_img_84]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_85'}, page_content='[Image: page_0_img_85]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_86'}, page_content='[Image: page_0_img_86]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_87'}, page_content='[Image: page_0_img_87]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_88'}, page_content='[Image: page_0_img_88]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_89'}, page_content='[Image: page_0_img_89]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_90'}, page_content='[Image: page_0_img_90]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_91'}, page_content='[Image: page_0_img_91]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_92'}, page_content='[Image: page_0_img_92]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_93'}, page_content='[Image: page_0_img_93]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_94'}, page_content='[Image: page_0_img_94]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_95'}, page_content='[Image: page_0_img_95]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_96'}, page_content='[Image: page_0_img_96]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_97'}, page_content='[Image: page_0_img_97]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_98'}, page_content='[Image: page_0_img_98]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_99'}, page_content='[Image: page_0_img_99]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_100'}, page_content='[Image: page_0_img_100]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_101'}, page_content='[Image: page_0_img_101]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_102'}, page_content='[Image: page_0_img_102]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_103'}, page_content='[Image: page_0_img_103]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_104'}, page_content='[Image: page_0_img_104]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_105'}, page_content='[Image: page_0_img_105]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_106'}, page_content='[Image: page_0_img_106]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_107'}, page_content='[Image: page_0_img_107]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_108'}, page_content='[Image: page_0_img_108]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_109'}, page_content='[Image: page_0_img_109]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_110'}, page_content='[Image: page_0_img_110]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_111'}, page_content='[Image: page_0_img_111]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_112'}, page_content='[Image: page_0_img_112]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_113'}, page_content='[Image: page_0_img_113]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_114'}, page_content='[Image: page_0_img_114]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_115'}, page_content='[Image: page_0_img_115]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_116'}, page_content='[Image: page_0_img_116]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_117'}, page_content='[Image: page_0_img_117]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_118'}, page_content='[Image: page_0_img_118]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_119'}, page_content='[Image: page_0_img_119]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_120'}, page_content='[Image: page_0_img_120]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_121'}, page_content='[Image: page_0_img_121]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_122'}, page_content='[Image: page_0_img_122]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_123'}, page_content='[Image: page_0_img_123]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_124'}, page_content='[Image: page_0_img_124]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_125'}, page_content='[Image: page_0_img_125]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_126'}, page_content='[Image: page_0_img_126]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_127'}, page_content='[Image: page_0_img_127]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_128'}, page_content='[Image: page_0_img_128]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_129'}, page_content='[Image: page_0_img_129]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_130'}, page_content='[Image: page_0_img_130]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_131'}, page_content='[Image: page_0_img_131]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_132'}, page_content='[Image: page_0_img_132]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_133'}, page_content='[Image: page_0_img_133]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_134'}, page_content='[Image: page_0_img_134]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_135'}, page_content='[Image: page_0_img_135]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_136'}, page_content='[Image: page_0_img_136]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_137'}, page_content='[Image: page_0_img_137]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_138'}, page_content='[Image: page_0_img_138]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_139'}, page_content='[Image: page_0_img_139]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_140'}, page_content='[Image: page_0_img_140]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_141'}, page_content='[Image: page_0_img_141]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_142'}, page_content='[Image: page_0_img_142]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_143'}, page_content='[Image: page_0_img_143]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_144'}, page_content='[Image: page_0_img_144]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_145'}, page_content='[Image: page_0_img_145]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_146'}, page_content='[Image: page_0_img_146]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_147'}, page_content='[Image: page_0_img_147]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_148'}, page_content='[Image: page_0_img_148]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_149'}, page_content='[Image: page_0_img_149]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_150'}, page_content='[Image: page_0_img_150]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_151'}, page_content='[Image: page_0_img_151]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_152'}, page_content='[Image: page_0_img_152]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_153'}, page_content='[Image: page_0_img_153]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_154'}, page_content='[Image: page_0_img_154]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_155'}, page_content='[Image: page_0_img_155]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_156'}, page_content='[Image: page_0_img_156]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_157'}, page_content='[Image: page_0_img_157]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_158'}, page_content='[Image: page_0_img_158]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_159'}, page_content='[Image: page_0_img_159]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_160'}, page_content='[Image: page_0_img_160]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_161'}, page_content='[Image: page_0_img_161]'),
#  Document(metadata={'page': 0, 'type': 'image', 'image_id': 'page_0_img_162'}, page_content='[Image: page_0_img_162]'),
#  Document(metadata={'page': 1, 'type': 'text'}, page_content='• Floral characteristics\nare the most\ncommonly  used\nf\nt\nt\nid\ntif\nFlowers\nfeatures to identify\nplants'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_0'}, page_content='[Image: page_1_img_0]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_1'}, page_content='[Image: page_1_img_1]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_2'}, page_content='[Image: page_1_img_2]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_3'}, page_content='[Image: page_1_img_3]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_4'}, page_content='[Image: page_1_img_4]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_5'}, page_content='[Image: page_1_img_5]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_6'}, page_content='[Image: page_1_img_6]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_7'}, page_content='[Image: page_1_img_7]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_8'}, page_content='[Image: page_1_img_8]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_9'}, page_content='[Image: page_1_img_9]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_10'}, page_content='[Image: page_1_img_10]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_11'}, page_content='[Image: page_1_img_11]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_12'}, page_content='[Image: page_1_img_12]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_13'}, page_content='[Image: page_1_img_13]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_14'}, page_content='[Image: page_1_img_14]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_15'}, page_content='[Image: page_1_img_15]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_16'}, page_content='[Image: page_1_img_16]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_17'}, page_content='[Image: page_1_img_17]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_18'}, page_content='[Image: page_1_img_18]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_19'}, page_content='[Image: page_1_img_19]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_20'}, page_content='[Image: page_1_img_20]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_21'}, page_content='[Image: page_1_img_21]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_22'}, page_content='[Image: page_1_img_22]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_23'}, page_content='[Image: page_1_img_23]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_24'}, page_content='[Image: page_1_img_24]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_25'}, page_content='[Image: page_1_img_25]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_26'}, page_content='[Image: page_1_img_26]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_27'}, page_content='[Image: page_1_img_27]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_28'}, page_content='[Image: page_1_img_28]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_29'}, page_content='[Image: page_1_img_29]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_30'}, page_content='[Image: page_1_img_30]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_31'}, page_content='[Image: page_1_img_31]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_32'}, page_content='[Image: page_1_img_32]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_33'}, page_content='[Image: page_1_img_33]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_34'}, page_content='[Image: page_1_img_34]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_35'}, page_content='[Image: page_1_img_35]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_36'}, page_content='[Image: page_1_img_36]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_37'}, page_content='[Image: page_1_img_37]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_38'}, page_content='[Image: page_1_img_38]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_39'}, page_content='[Image: page_1_img_39]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_40'}, page_content='[Image: page_1_img_40]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_41'}, page_content='[Image: page_1_img_41]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_42'}, page_content='[Image: page_1_img_42]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_43'}, page_content='[Image: page_1_img_43]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_44'}, page_content='[Image: page_1_img_44]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_45'}, page_content='[Image: page_1_img_45]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_46'}, page_content='[Image: page_1_img_46]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_47'}, page_content='[Image: page_1_img_47]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_48'}, page_content='[Image: page_1_img_48]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_49'}, page_content='[Image: page_1_img_49]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_50'}, page_content='[Image: page_1_img_50]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_51'}, page_content='[Image: page_1_img_51]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_52'}, page_content='[Image: page_1_img_52]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_53'}, page_content='[Image: page_1_img_53]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_54'}, page_content='[Image: page_1_img_54]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_55'}, page_content='[Image: page_1_img_55]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_56'}, page_content='[Image: page_1_img_56]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_57'}, page_content='[Image: page_1_img_57]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_58'}, page_content='[Image: page_1_img_58]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_59'}, page_content='[Image: page_1_img_59]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_60'}, page_content='[Image: page_1_img_60]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_61'}, page_content='[Image: page_1_img_61]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_62'}, page_content='[Image: page_1_img_62]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_63'}, page_content='[Image: page_1_img_63]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_64'}, page_content='[Image: page_1_img_64]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_65'}, page_content='[Image: page_1_img_65]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_66'}, page_content='[Image: page_1_img_66]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_67'}, page_content='[Image: page_1_img_67]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_68'}, page_content='[Image: page_1_img_68]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_69'}, page_content='[Image: page_1_img_69]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_70'}, page_content='[Image: page_1_img_70]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_71'}, page_content='[Image: page_1_img_71]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_72'}, page_content='[Image: page_1_img_72]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_73'}, page_content='[Image: page_1_img_73]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_74'}, page_content='[Image: page_1_img_74]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_75'}, page_content='[Image: page_1_img_75]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_76'}, page_content='[Image: page_1_img_76]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_77'}, page_content='[Image: page_1_img_77]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_78'}, page_content='[Image: page_1_img_78]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_79'}, page_content='[Image: page_1_img_79]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_80'}, page_content='[Image: page_1_img_80]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_81'}, page_content='[Image: page_1_img_81]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_82'}, page_content='[Image: page_1_img_82]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_83'}, page_content='[Image: page_1_img_83]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_84'}, page_content='[Image: page_1_img_84]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_85'}, page_content='[Image: page_1_img_85]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_86'}, page_content='[Image: page_1_img_86]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_87'}, page_content='[Image: page_1_img_87]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_88'}, page_content='[Image: page_1_img_88]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_89'}, page_content='[Image: page_1_img_89]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_90'}, page_content='[Image: page_1_img_90]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_91'}, page_content='[Image: page_1_img_91]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_92'}, page_content='[Image: page_1_img_92]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_93'}, page_content='[Image: page_1_img_93]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_94'}, page_content='[Image: page_1_img_94]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_95'}, page_content='[Image: page_1_img_95]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_96'}, page_content='[Image: page_1_img_96]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_97'}, page_content='[Image: page_1_img_97]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_98'}, page_content='[Image: page_1_img_98]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_99'}, page_content='[Image: page_1_img_99]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_100'}, page_content='[Image: page_1_img_100]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_101'}, page_content='[Image: page_1_img_101]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_102'}, page_content='[Image: page_1_img_102]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_103'}, page_content='[Image: page_1_img_103]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_104'}, page_content='[Image: page_1_img_104]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_105'}, page_content='[Image: page_1_img_105]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_106'}, page_content='[Image: page_1_img_106]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_107'}, page_content='[Image: page_1_img_107]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_108'}, page_content='[Image: page_1_img_108]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_109'}, page_content='[Image: page_1_img_109]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_110'}, page_content='[Image: page_1_img_110]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_111'}, page_content='[Image: page_1_img_111]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_112'}, page_content='[Image: page_1_img_112]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_113'}, page_content='[Image: page_1_img_113]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_114'}, page_content='[Image: page_1_img_114]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_115'}, page_content='[Image: page_1_img_115]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_116'}, page_content='[Image: page_1_img_116]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_117'}, page_content='[Image: page_1_img_117]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_118'}, page_content='[Image: page_1_img_118]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_119'}, page_content='[Image: page_1_img_119]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_120'}, page_content='[Image: page_1_img_120]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_121'}, page_content='[Image: page_1_img_121]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_122'}, page_content='[Image: page_1_img_122]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_123'}, page_content='[Image: page_1_img_123]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_124'}, page_content='[Image: page_1_img_124]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_125'}, page_content='[Image: page_1_img_125]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_126'}, page_content='[Image: page_1_img_126]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_127'}, page_content='[Image: page_1_img_127]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_128'}, page_content='[Image: page_1_img_128]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_129'}, page_content='[Image: page_1_img_129]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_130'}, page_content='[Image: page_1_img_130]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_131'}, page_content='[Image: page_1_img_131]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_132'}, page_content='[Image: page_1_img_132]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_133'}, page_content='[Image: page_1_img_133]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_134'}, page_content='[Image: page_1_img_134]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_135'}, page_content='[Image: page_1_img_135]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_136'}, page_content='[Image: page_1_img_136]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_137'}, page_content='[Image: page_1_img_137]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_138'}, page_content='[Image: page_1_img_138]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_139'}, page_content='[Image: page_1_img_139]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_140'}, page_content='[Image: page_1_img_140]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_141'}, page_content='[Image: page_1_img_141]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_142'}, page_content='[Image: page_1_img_142]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_143'}, page_content='[Image: page_1_img_143]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_144'}, page_content='[Image: page_1_img_144]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_145'}, page_content='[Image: page_1_img_145]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_146'}, page_content='[Image: page_1_img_146]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_147'}, page_content='[Image: page_1_img_147]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_148'}, page_content='[Image: page_1_img_148]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_149'}, page_content='[Image: page_1_img_149]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_150'}, page_content='[Image: page_1_img_150]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_151'}, page_content='[Image: page_1_img_151]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_152'}, page_content='[Image: page_1_img_152]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_153'}, page_content='[Image: page_1_img_153]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_154'}, page_content='[Image: page_1_img_154]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_155'}, page_content='[Image: page_1_img_155]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_156'}, page_content='[Image: page_1_img_156]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_157'}, page_content='[Image: page_1_img_157]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_158'}, page_content='[Image: page_1_img_158]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_159'}, page_content='[Image: page_1_img_159]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_160'}, page_content='[Image: page_1_img_160]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_161'}, page_content='[Image: page_1_img_161]'),
#  Document(metadata={'page': 1, 'type': 'image', 'image_id': 'page_1_img_162'}, page_content='[Image: page_1_img_162]'),
#  Document(metadata={'page': 2, 'type': 'text'}, page_content='Flower\n• A typical flower is a\nstem tip bearing two\nwhorls of\nappendages, two\nare sterile and two\nare fertile\n• All four whorls are\nconsidered to be\nmodified leaves'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_0'}, page_content='[Image: page_2_img_0]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_1'}, page_content='[Image: page_2_img_1]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_2'}, page_content='[Image: page_2_img_2]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_3'}, page_content='[Image: page_2_img_3]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_4'}, page_content='[Image: page_2_img_4]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_5'}, page_content='[Image: page_2_img_5]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_6'}, page_content='[Image: page_2_img_6]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_7'}, page_content='[Image: page_2_img_7]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_8'}, page_content='[Image: page_2_img_8]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_9'}, page_content='[Image: page_2_img_9]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_10'}, page_content='[Image: page_2_img_10]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_11'}, page_content='[Image: page_2_img_11]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_12'}, page_content='[Image: page_2_img_12]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_13'}, page_content='[Image: page_2_img_13]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_14'}, page_content='[Image: page_2_img_14]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_15'}, page_content='[Image: page_2_img_15]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_16'}, page_content='[Image: page_2_img_16]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_17'}, page_content='[Image: page_2_img_17]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_18'}, page_content='[Image: page_2_img_18]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_19'}, page_content='[Image: page_2_img_19]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_20'}, page_content='[Image: page_2_img_20]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_21'}, page_content='[Image: page_2_img_21]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_22'}, page_content='[Image: page_2_img_22]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_23'}, page_content='[Image: page_2_img_23]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_24'}, page_content='[Image: page_2_img_24]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_25'}, page_content='[Image: page_2_img_25]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_26'}, page_content='[Image: page_2_img_26]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_27'}, page_content='[Image: page_2_img_27]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_28'}, page_content='[Image: page_2_img_28]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_29'}, page_content='[Image: page_2_img_29]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_30'}, page_content='[Image: page_2_img_30]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_31'}, page_content='[Image: page_2_img_31]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_32'}, page_content='[Image: page_2_img_32]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_33'}, page_content='[Image: page_2_img_33]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_34'}, page_content='[Image: page_2_img_34]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_35'}, page_content='[Image: page_2_img_35]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_36'}, page_content='[Image: page_2_img_36]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_37'}, page_content='[Image: page_2_img_37]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_38'}, page_content='[Image: page_2_img_38]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_39'}, page_content='[Image: page_2_img_39]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_40'}, page_content='[Image: page_2_img_40]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_41'}, page_content='[Image: page_2_img_41]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_42'}, page_content='[Image: page_2_img_42]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_43'}, page_content='[Image: page_2_img_43]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_44'}, page_content='[Image: page_2_img_44]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_45'}, page_content='[Image: page_2_img_45]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_46'}, page_content='[Image: page_2_img_46]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_47'}, page_content='[Image: page_2_img_47]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_48'}, page_content='[Image: page_2_img_48]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_49'}, page_content='[Image: page_2_img_49]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_50'}, page_content='[Image: page_2_img_50]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_51'}, page_content='[Image: page_2_img_51]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_52'}, page_content='[Image: page_2_img_52]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_53'}, page_content='[Image: page_2_img_53]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_54'}, page_content='[Image: page_2_img_54]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_55'}, page_content='[Image: page_2_img_55]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_56'}, page_content='[Image: page_2_img_56]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_57'}, page_content='[Image: page_2_img_57]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_58'}, page_content='[Image: page_2_img_58]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_59'}, page_content='[Image: page_2_img_59]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_60'}, page_content='[Image: page_2_img_60]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_61'}, page_content='[Image: page_2_img_61]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_62'}, page_content='[Image: page_2_img_62]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_63'}, page_content='[Image: page_2_img_63]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_64'}, page_content='[Image: page_2_img_64]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_65'}, page_content='[Image: page_2_img_65]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_66'}, page_content='[Image: page_2_img_66]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_67'}, page_content='[Image: page_2_img_67]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_68'}, page_content='[Image: page_2_img_68]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_69'}, page_content='[Image: page_2_img_69]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_70'}, page_content='[Image: page_2_img_70]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_71'}, page_content='[Image: page_2_img_71]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_72'}, page_content='[Image: page_2_img_72]'),
#  Document(metadata={'page': 2, 'type': 'image', 'image_id': 'page_2_img_73'}, page_content='[Image: page_2_img_73]'),
# ...
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_46'}, page_content='[Image: page_5_img_46]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_47'}, page_content='[Image: page_5_img_47]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_48'}, page_content='[Image: page_5_img_48]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_49'}, page_content='[Image: page_5_img_49]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_50'}, page_content='[Image: page_5_img_50]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_51'}, page_content='[Image: page_5_img_51]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_52'}, page_content='[Image: page_5_img_52]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_53'}, page_content='[Image: page_5_img_53]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_54'}, page_content='[Image: page_5_img_54]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_55'}, page_content='[Image: page_5_img_55]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_56'}, page_content='[Image: page_5_img_56]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_57'}, page_content='[Image: page_5_img_57]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_58'}, page_content='[Image: page_5_img_58]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_59'}, page_content='[Image: page_5_img_59]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_60'}, page_content='[Image: page_5_img_60]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_61'}, page_content='[Image: page_5_img_61]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_62'}, page_content='[Image: page_5_img_62]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_63'}, page_content='[Image: page_5_img_63]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_64'}, page_content='[Image: page_5_img_64]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_65'}, page_content='[Image: page_5_img_65]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_66'}, page_content='[Image: page_5_img_66]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_67'}, page_content='[Image: page_5_img_67]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_68'}, page_content='[Image: page_5_img_68]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_69'}, page_content='[Image: page_5_img_69]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_70'}, page_content='[Image: page_5_img_70]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_71'}, page_content='[Image: page_5_img_71]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_72'}, page_content='[Image: page_5_img_72]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_73'}, page_content='[Image: page_5_img_73]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_74'}, page_content='[Image: page_5_img_74]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_75'}, page_content='[Image: page_5_img_75]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_76'}, page_content='[Image: page_5_img_76]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_77'}, page_content='[Image: page_5_img_77]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_78'}, page_content='[Image: page_5_img_78]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_79'}, page_content='[Image: page_5_img_79]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_80'}, page_content='[Image: page_5_img_80]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_81'}, page_content='[Image: page_5_img_81]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_82'}, page_content='[Image: page_5_img_82]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_83'}, page_content='[Image: page_5_img_83]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_84'}, page_content='[Image: page_5_img_84]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_85'}, page_content='[Image: page_5_img_85]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_86'}, page_content='[Image: page_5_img_86]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_87'}, page_content='[Image: page_5_img_87]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_88'}, page_content='[Image: page_5_img_88]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_89'}, page_content='[Image: page_5_img_89]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_90'}, page_content='[Image: page_5_img_90]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_91'}, page_content='[Image: page_5_img_91]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_92'}, page_content='[Image: page_5_img_92]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_93'}, page_content='[Image: page_5_img_93]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_94'}, page_content='[Image: page_5_img_94]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_95'}, page_content='[Image: page_5_img_95]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_96'}, page_content='[Image: page_5_img_96]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_97'}, page_content='[Image: page_5_img_97]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_98'}, page_content='[Image: page_5_img_98]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_99'}, page_content='[Image: page_5_img_99]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_100'}, page_content='[Image: page_5_img_100]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_101'}, page_content='[Image: page_5_img_101]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_102'}, page_content='[Image: page_5_img_102]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_103'}, page_content='[Image: page_5_img_103]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_104'}, page_content='[Image: page_5_img_104]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_105'}, page_content='[Image: page_5_img_105]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_106'}, page_content='[Image: page_5_img_106]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_107'}, page_content='[Image: page_5_img_107]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_108'}, page_content='[Image: page_5_img_108]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_109'}, page_content='[Image: page_5_img_109]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_110'}, page_content='[Image: page_5_img_110]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_111'}, page_content='[Image: page_5_img_111]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_112'}, page_content='[Image: page_5_img_112]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_113'}, page_content='[Image: page_5_img_113]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_114'}, page_content='[Image: page_5_img_114]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_115'}, page_content='[Image: page_5_img_115]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_116'}, page_content='[Image: page_5_img_116]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_117'}, page_content='[Image: page_5_img_117]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_118'}, page_content='[Image: page_5_img_118]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_119'}, page_content='[Image: page_5_img_119]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_120'}, page_content='[Image: page_5_img_120]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_121'}, page_content='[Image: page_5_img_121]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_122'}, page_content='[Image: page_5_img_122]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_123'}, page_content='[Image: page_5_img_123]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_124'}, page_content='[Image: page_5_img_124]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_125'}, page_content='[Image: page_5_img_125]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_126'}, page_content='[Image: page_5_img_126]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_127'}, page_content='[Image: page_5_img_127]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_128'}, page_content='[Image: page_5_img_128]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_129'}, page_content='[Image: page_5_img_129]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_130'}, page_content='[Image: page_5_img_130]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_131'}, page_content='[Image: page_5_img_131]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_132'}, page_content='[Image: page_5_img_132]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_133'}, page_content='[Image: page_5_img_133]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_134'}, page_content='[Image: page_5_img_134]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_135'}, page_content='[Image: page_5_img_135]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_136'}, page_content='[Image: page_5_img_136]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_137'}, page_content='[Image: page_5_img_137]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_138'}, page_content='[Image: page_5_img_138]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_139'}, page_content='[Image: page_5_img_139]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_140'}, page_content='[Image: page_5_img_140]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_141'}, page_content='[Image: page_5_img_141]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_142'}, page_content='[Image: page_5_img_142]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_143'}, page_content='[Image: page_5_img_143]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_144'}, page_content='[Image: page_5_img_144]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_145'}, page_content='[Image: page_5_img_145]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_146'}, page_content='[Image: page_5_img_146]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_147'}, page_content='[Image: page_5_img_147]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_148'}, page_content='[Image: page_5_img_148]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_149'}, page_content='[Image: page_5_img_149]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_150'}, page_content='[Image: page_5_img_150]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_151'}, page_content='[Image: page_5_img_151]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_152'}, page_content='[Image: page_5_img_152]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_153'}, page_content='[Image: page_5_img_153]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_154'}, page_content='[Image: page_5_img_154]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_155'}, page_content='[Image: page_5_img_155]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_156'}, page_content='[Image: page_5_img_156]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_157'}, page_content='[Image: page_5_img_157]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_158'}, page_content='[Image: page_5_img_158]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_159'}, page_content='[Image: page_5_img_159]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_160'}, page_content='[Image: page_5_img_160]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_161'}, page_content='[Image: page_5_img_161]'),
#  Document(metadata={'page': 5, 'type': 'image', 'image_id': 'page_5_img_162'}, page_content='[Image: page_5_img_162]'),
#  Document(metadata={'page': 6, 'type': 'text'}, page_content="Flower Anatomy\nAndroecium (from Greek\nandros oikia: man's\nhouse): one or more\nstamens, each with a\n,\nfilament topped by an\nanther where pollen is\nproduced.\nPollen contains the male\ngametes."),
#  Document(metadata={'page': 6, 'type': 'image', 'image_id': 'page_6_img_0'}, page_content='[Image: page_6_img_0]'),
#  Document(metadata={'page': 6, 'type': 'image', 'image_id': 'page_6_img_1'}, page_content='[Image: page_6_img_1]'),
#  Document(metadata={'page': 6, 'type': 'image', 'image_id': 'page_6_img_2'}, page_content='[Image: page_6_img_2]'),
#  Document(metadata={'page': 6, 'type': 'image', 'image_id': 'page_6_img_3'}, page_content='[Image: page_6_img_3]'),
#  Document(metadata={'page': 6, 'type': 'image', 'image_id': 'page_6_img_4'}, page_content='[Image: page_6_img_4]'),
#  Document(metadata={'page': 6, 'type': 'image', 'image_id': 'page_6_img_5'}, page_content='[Image: page_6_img_5]'),
#  Document(metadata={'page': 6, 'type': 'image', 'image_id': 'page_6_img_6'}, page_content='[Image: page_6_img_6]'),
#  Document(metadata={'page': 6, 'type': 'image', 'image_id': 'page_6_img_7'}, page_content='[Image: page_6_img_7]'),
#  Document(metadata={'page': 6, 'type': 'image', 'image_id': 'page_6_img_8'}, page_content='[Image: page_6_img_8]'),
#  Document(metadata={'page': 6, 'type': 'image', 'image_id': 'page_6_img_9'}, page_content='[Image: page_6_img_9]'),
#  Document(metadata={'page': 6, 'type': 'image', 'image_id': 'page_6_img_10'}, page_content='[Image: page_6_img_10]'),
#  Document(metadata={'page': 6, 'type': 'image', 'image_id': 'page_6_img_11'}, page_content='[Image: page_6_img_11]'),
#  Document(metadata={'page': 6, 'type': 'image', 'image_id': 'page_6_img_12'}, page_content='[Image: page_6_img_12]'),
#  Document(metadata={'page': 6, 'type': 'image', 'image_id': 'page_6_img_13'}, page_content='[Image: page_6_img_13]'),
#  Document(metadata={'page': 6, 'type': 'image', 'image_id': 'page_6_img_14'}, page_content='[Image: page_6_img_14]'),
#  ...]

# %%
# Create unified FAISS vector store with CLIP embeddings
embeddings_array = np.array(all_embeddings)
embeddings_array
# Out:
# array([[-0.04384758, -0.00486706,  0.02732429, ...,  0.02509783,
#         -0.0129518 , -0.03269687],
#        [ 0.03706964,  0.03470185, -0.00674659, ...,  0.03387407,
#          0.01132378,  0.009261  ],
#        [ 0.01944484,  0.02597684,  0.00277657, ...,  0.04933508,
#          0.04852957,  0.02182267],
#        ...,
#        [ 0.01664223,  0.01754193,  0.00626485, ...,  0.06931599,
#          0.02405416,  0.02622443],
#        [-0.01750883,  0.00059912,  0.03032437, ...,  0.06875303,
#         -0.01199512,  0.03460951],
#        [ 0.03061348,  0.0165642 ,  0.01175014, ...,  0.05474591,
#          0.02658661,  0.00393654]], shape=(9182, 512), dtype=float32)

# %%
# Create custom FAISS index since we have precomputed embeddings
vector_store = FAISS.from_embeddings(
    text_embeddings=[(doc.page_content, emb) for doc, emb in zip(all_docs, embeddings_array)],
    embedding=None,  # We're using precomputed embeddings
    metadatas=[doc.metadata for doc in all_docs]
)
vector_store
# Out:
# `embedding_function` is expected to be an Embeddings object, support for passing in a function will soon be removed.

# %%
def retrieve_multimodal(query, k=5):
    """Unified retrieval using CLIP embeddings for both text and images."""
    # Embed query using CLIP
    query_embedding = embed_text(query)
    
    # Search in unified vector store
    results = vector_store.similarity_search_by_vector(
        embedding=query_embedding,
        k=k
    )
    
    return results

# %%
def create_multimodal_message(query, retrieved_docs):
    """Create a message with both text and images for GPT-4V."""
    content = []
    
    # Add the query
    content.append({
        "type": "text",
        "text": f"Question: {query}\n\nContext:\n"
    })
    
    # Separate text and image documents
    text_docs = [doc for doc in retrieved_docs if doc.metadata.get("type") == "text"]
    image_docs = [doc for doc in retrieved_docs if doc.metadata.get("type") == "image"]
    
    # Add text context
    if text_docs:
        text_context = "\n\n".join([
            f"[Page {doc.metadata['page']}]: {doc.page_content}"
            for doc in text_docs
        ])
        content.append({
            "type": "text",
            "text": f"Text excerpts:\n{text_context}\n"
        })
    
    # Add images
    for doc in image_docs:
        image_id = doc.metadata.get("image_id")
        if image_id and image_id in image_data_store:
            content.append({
                "type": "text",
                "text": f"\n[Image from page {doc.metadata['page']}]:\n"
            })
            content.append({
                "type": "image_url",
                "image_url": {
                    "url": f"data:image/png;base64,{image_data_store[image_id]}"
                }
            })
    
    # Add instruction
    content.append({
        "type": "text",
        "text": "\n\nPlease answer the question based on the provided text and images."
    })
    
    return HumanMessage(content=content)

# %%
def multimodal_pdf_rag_pipeline(query):
    """Main pipeline for multimodal RAG."""
    # Retrieve relevant documents
    context_docs = retrieve_multimodal(query, k=5)
    
    # Create multimodal message
    message = create_multimodal_message(query, context_docs)
    
    # Get response from GPT-4V
    response = llm.invoke([message])
    
    # Print retrieved context info
    print(f"\nRetrieved {len(context_docs)} documents:")
    for doc in context_docs:
        doc_type = doc.metadata.get("type", "unknown")
        page = doc.metadata.get("page", "?")
        if doc_type == "text":
            preview = doc.page_content[:100] + "..." if len(doc.page_content) > 100 else doc.page_content
            print(f"  - Text from page {page}: {preview}")
        else:
            print(f"  - Image from page {page}")
    print("\n")
    
    return response

# %%
if __name__ == "__main__":
    # Example queries
    queries = [
        
        "Tell me the name of the flower in red?"
        
    ]
    
    for query in queries:
        print(f"\nQuery: {query}")
        print("-" * 50)
        answer = multimodal_pdf_rag_pipeline(query)
        print(f"Answer: {answer}")
        print("=" * 70)
# Out:
# Query: Tell me the name of the flower in red?
# --------------------------------------------------
#
# Retrieved 5 documents:
#   - Text from page 1: • Floral characteristics
# are the most
# commonly  used
# f
# t
# t
# id
# tif
# Flowers
# features to identify
# plant...
#   - Text from page 9: Flower Structure Variation
# imperfect
# perfect
# imperfect
#   - Text from page 0: Morphology of flower
#   - Text from page 38: could also be upward
#   - Text from page 30: inserted
# exserted
#
#
# Answer: Based on the provided text and images, the name of the red flower is not mentioned. The images are general diagrams used to explain the "Morphology of flower" and its parts, such as petals and sepals, rather than identifying a specific species.
# ======================================================================
